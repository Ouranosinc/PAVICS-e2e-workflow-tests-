# %% [markdown]
# # Various stress tests to see if instance and services response adequately

# %% [markdown]
# ## Inputs and Configuration

# %%
# NBVAL_IGNORE_OUTPUT

import os
import random
import requests
import time
from datetime import datetime 
from inspect import cleandoc
from dataclasses import dataclass
import threading
from threading import Thread


PAVICS_HOST = os.getenv("PAVICS_HOST", "pavics.ouranos.ca").rstrip("/")
if not PAVICS_HOST:
    raise ValueError("Cannot run test without a PAVICS_HOST value.")

PAVICS_URL = f"https://{PAVICS_HOST}"
VERIFY_SSL = True if "DISABLE_VERIFY_SSL" not in os.environ else False
MAGPIE_URL = PAVICS_URL + "/magpie"
TWITCHER_PROXY = "/twitcher/ows/proxy"
TWITCHER_URL = PAVICS_URL + TWITCHER_PROXY
TWITCHER_URL = os.getenv("TWITCHER_URL") or TWITCHER_URL

# test config
TEST_WPS_BIRDS = str(os.getenv("TEST_WPS_BIRDS", "finch,raven,hummingbird"))
TEST_WPS_BIRDS = [bird.strip() for bird in TEST_WPS_BIRDS.split(",")]
if not len(TEST_WPS_BIRDS):
    raise ValueError("Cannot run test without at least one service in TEST_WPS_BIRDS.")

TEST_MAX_AVG_TIME = int(os.getenv("TEST_MAX_AVG_TIME", 1))     # maximum allowed request seconds on average for success
TEST_MAX_ERR_CODE = int(os.getenv("TEST_MAX_ERR_CODE", 0))     # maximum allowed amount of incorrect request status code
TEST_TIMEOUT_ABORT = int(os.getenv("TEST_TIMEOUT_ABORT", 5))   # maximum timeout duration to wait before abort request
TEST_TIMEOUT_RETRY = int(os.getenv("TEST_ABORT_THRESHOLD", 3)) # maximum request timeout retries before bird is aborted

TEST_RUNS_WPS = int(os.getenv("TEST_RUNS_WPS", 100))         # number of requests per tested bird
TEST_RUNS_THREDDS = int(os.getenv("TEST_RUNS_THREDDS", 500)) # number of requests for thredds test

TEST_N_THREADS_WPS = int(os.getenv("TEST_N_THREADS_WPS", 3))         # number of threads testing in parallel each bird
TEST_N_THREADS_THREDDS = int(os.getenv("TEST_N_THREADS_THREDDS", 5)) # number of threads testing in parallel thredds


print(f"PAVICS_HOST:    [{PAVICS_HOST}]")
print(f"TWITCHER_URL:   [{TWITCHER_URL}]")
print(f"TEST_WPS_BIRDS: {TEST_WPS_BIRDS}")
# Out:
# PAVICS_HOST:    [pavics.ouranos.ca]
# TWITCHER_URL:   [https://pavics.ouranos.ca/twitcher/ows/proxy]
# TEST_WPS_BIRDS: ['finch', 'raven', 'hummingbird']

# %% [markdown]
# ## Utilities

# %%
class StressTestProgression:
    """
    Class used by threads to keep track of the amount of request and progression of the tests. 
    Passed to each threads so that we know the progression in between threads
    """
    def __init__(self, n_threads: int, runs_per_threads: int):
        """
        :param n_threads: number of threads
        :param runs_per_threads: number of stress test request
        """
        self.count = 0
        self.n_threads = n_threads
        self.runs_per_threads = runs_per_threads
        self.total_runs = runs_per_threads * n_threads
        self.failed_threads_count: int = 0
        self.failed_requests_count: int = 0
        self.failed_stress_test_results = []

    def __str__(self):
        return str(self.__dict__)


    def increase(self, amount):
        self.count = self.count + amount

        if threading.current_thread().name:
            thread_name = threading.current_thread().name
            print(f"    {thread_name} --> Progress : {self.count}/{self.total_runs}   ")
        else:
            print(f"    Progress : {self.count}/{self.total_runs} ")

    def fail_report(self):
        report_error_message = "This test failed due to bad code received from the requests."
        report_error_message += f"\n Number of failed thread(s) : {self.failed_threads_count}/ {self.n_threads}"
        report_error_message += f"\n Number of failed requests : {self.failed_requests_count}/{self.total_runs}"
        
        for failed_result in self.failed_stress_test_results:
            i = 0
            for code in list(failed_result.codes):
                if code is failed_result.code:
                    del failed_result.codes[i:i+1]
                    del failed_result.delta[i:i+1]
                    del failed_result.times[i:i+1]
                    del failed_result.timestamps[i:i+1]
                    i -= 1
                i+= 1
                
            report_error_message += f"\n\n\n Failed Test"
            report_error_message += f"\n {failed_result}"
            
            report_error_message += f"\n\n === Exceptions ==="
            for i, exception in enumerate(failed_result.request_exceptions):
                code = failed_result.codes[i]
                if code == 408:
                    reason = "Request TimeOut (Client Side)"
                    exception_text = exception
                else :
                    reason = exception.response.reason
                    exception_text = exception.response.text
                    
                report_error_message += f"\n\n {i+1}. {code} {reason}"
                report_error_message += f"\n {exception_text}"
                
        return report_error_message


        
@dataclass
class StressTestResult:
    code: int = 200
    runs: int = 0
    max_avg_time: float = 0
    max_err_code: int = 0
    timeout_abort: int = 0
    timeout_retry: int = 0
    timeout_count: int = 0
    method: str = "GET"
    url: str = None
    request_args: dict = None
    status: int = 0  # see description of stress-test
    codes = []
    delta = []
    times = []
    timestamps = []
    request_exceptions = []

    @property
    def avg_time(self):
        return sum(self.times) / self.runs

    @property
    def min_time(self):
        return min(self.times)

    @property
    def max_time(self):
        return max(self.times)

    @property
    def sum_err_code(self):
        return sum([code != self.code for code in self.codes])

    def __str__(self):
        columns = ["Run", "Codes", "Delta", "Times", "Timestamps"]
        idx = len(str(self.runs))
        r = max(len(columns[0]), idx)
        w = 22
        header = "".join(f"{c:>{w if i else r}}" for i, c in enumerate(columns))
        offset = 16  # spaces offset of result lines, relative to this file
        data = [f"{i+1:>{r+(offset if i else 0)}}"
                f"{('(!) ' if c != self.code else '(x) ' if self.code == 408 else '') + str(c):>{w}}"
                f"{d:>{w-1}.3f}s"
                f"{t:>{w-1}.3f}s"
                f"{ts:>{w}}"
                for i, (c, d, t, ts)
                in enumerate(zip(self.codes, self.delta, self.times, self.timestamps))]
        lines = "\n".join(data)
        summary = "Undefined failure result status condition encountered."
        if self.status == 0:
            summary = [
                "All passing conditions have been achieved.",
            ]
        elif self.status == -1:
            summary = [
                f"Detected {self.sum_err_code} erroneous HTTP codes not equal to expected {self.code}."
            ]
        elif self.status == -2:
            summary = [
                f"Detected regression with long request time.",
                f"Expected max-avg-time: ({self.max_avg_time:.3f}s <= {self.max_time:.3f}s)."
            ]
        elif self.status == -3:
            summary = [
                f"Maximum number of timeout ({self.timeout_abort}s) requests exceeded ({self.timeout_count}).",
                "Test was aborted to avoid further delays."
            ]
        summary.append(f"Test {'succeeded' if self.status == 0 else 'failed'} (status={self.status}).")
        summary = ("\n" + offset * " ").join(summary)
        return cleandoc(f"""
        Stress Test:
            Test:
                code: {self.code}
                runs: {self.runs}
                max-avg-time:  {self.max_avg_time}s
                max-err-code:  {self.max_err_code}
                sum-err-code:  {self.sum_err_code}
                timeout-abort: {self.timeout_abort}s
                timeout-retry: {self.timeout_retry}
                timeout-count: {self.timeout_count}
            Request:
                method: {self.method}
                url:    {self.url}
                args:   {self.request_args}
            Times:
                min: {self.min_time:.3f}s
                avg: {self.avg_time:.3f}s
                max: {self.max_time:.3f}s
            Results:
                {header}
                {lines}
            Summary:
                {summary}
        """)


def stress_test_requests(stress_test_progression: StressTestProgression,
                         url: str, method="GET", runs=100, code=200, delays=True,
                         max_err_code=0, max_avg_time=None,
                         abort_timeout=5, abort_retries=3, **req_kwargs) -> StressTestResult:
    """
    Executes the request for the number of demanded runs and validates the expected status is always returned.

    Outputs the results of each request and a summary of their execution time.
    If requested, also validates that all responses were returned on average faster than the maximum allowed time.

    :param stress_test_progression: StressTestProgress object to follow the progress of all requests
    :param url: endpoint to stress test
    :param method: HTTP method for request
    :param runs: number of stress test request
    :param code: expected HTTP code from requests
    :param delays: whether to apply small random delays between requests
       Otherwise, sequential requests are executed as quickly as possible, when the previous response is obtained.
    :param max_err_code: maximum amount of erroneous HTTP status code allowed to consider the test successful.
    :param max_avg_time: maximum average time of requests permitted to consider the test successful.
    :param abort_timeout: duration to wait until a request is aborted, sets 408 (Read Timeout) as HTTP status code.
    :param abort_retries: number of failed timeout requests allowed before abort of whole stress test for this endpoint.
    :returns:
        StressTestResult with individual request results and one of below status:
        -  0 (success) for no error and all conditions achieved
        - -1 (failure) for maximum amount of HTT error code reached
        - -2 (failure) for maximum request time on average reached
        - -3 (failure) for aborted test due to too many timeout
    """
    thread_name = threading.current_thread().name
    req_kwargs.pop("timeout", None)
    result = StressTestResult()
    result.runs = runs
    result.url = url
    result.method = method
    result.request_args = req_kwargs
    result.max_err_code = max_err_code
    result.max_avg_time = max_avg_time
    result.abort_timeout = abort_timeout
    result.abort_retries = abort_retries
    result.codes = []
    result.times = []
    result.timestamps = []
    result.request_exceptions = []
    result.delta = [0.] + [float((random.randint(1, 100) / 1000) if delays else 0) for _ in range(1, runs)]

    for i in range(runs):
        start = time.perf_counter()
        delta = None
        code = 520
        try:
            resp = requests.request(method, url, timeout=abort_timeout, **req_kwargs)
            resp.raise_for_status()
            code = resp.status_code
        except requests.exceptions.RequestException as exe:
            if isinstance(exe, requests.exceptions.Timeout):
                code = 408 # read timeout
                delta = abort_timeout
                result.timeout_count += 1
            else:
                code = exe.response.status_code
            result.codes.append(code)
            result.request_exceptions.append(exe)
            stress_test_progression.failed_requests_count += 1
        
        result.codes.append(code)
        result.times.append(delta or (time.perf_counter() - start))
        result.timestamps.append(datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
        if result.timeout_count > abort_timeout:
            result.status = -3
            print(f"Aborted: Too Many Timeout ({result.timeout_count})")
            return result
        if i == runs:
            break
        if result.delta[i]:
            time.sleep(result.delta[i])
        progress_update = 50
        if i!=0 and not (i-1)%progress_update:
            stress_test_progression.increase(progress_update)
    if max_avg_time and result.avg_time > max_avg_time:
        result.status = -2
    elif len([c for c in result.codes if c == code]) >= (runs - max_err_code):
        result.status = 0
    else:
        result.status = -1
    return result

# %%
def run_threads(target_test, url:str, execution_id:int = 1, n_threads:int = 1, runs_per_threads:int = 100):
    """
    This function launch n new thread with the target function to be executed.
    
    :param target_test: Function to be executed by the threads
    :param url: url to be called by the test
    :param execution_id: execution id to keep track of multiple execution, if this function is ran in a loop 
    :param n_threads: number of threads to be launched 
    :param runs_per_threads: number of stress test request per threads
    """

    stress_test_progression = StressTestProgression(n_threads, runs_per_threads)

    line = "-"*104
    print(line)
    print(f"URL Execution-{execution_id}")
    print(f'- Starting {n_threads} threads with {runs_per_threads} runs per threads targeting "{target_test.__name__}" function.')
    print(f"- URL : {url}")
    print(f"- Initial progression values : {stress_test_progression}")
    print(line)

    threads = [
        Thread(
            target=target_test,
            args=(url, stress_test_progression),
            name=f"Thread-{i+1}",
        )
        for i in range(n_threads)
    ]

    for thread in threads:
        thread.start()

    for thread in threads:
        thread.join()

    assert (
        stress_test_progression.failed_threads_count == 0
    ), stress_test_progression.fail_report()
    
    print(f"All threads passed {target_test.__name__} function.")


def stress_test(url: str, stress_test_progression: StressTestProgression):
    """
    This function launch N new thread with the target function to be executed.

    :param url: url to be requested
    :param stress_test_progression: StressTestProgression object to follow the progress of all requests
    """

    failed_count = 0
    failed_results = ""

    n_runs = stress_test_progression.runs_per_threads

    expect_status_code = 200
    results = stress_test_requests(stress_test_progression, url, runs=n_runs, code=expect_status_code,
                                   max_err_code=TEST_MAX_ERR_CODE, max_avg_time=TEST_MAX_AVG_TIME,
                                   abort_retries=TEST_TIMEOUT_RETRY, abort_timeout=TEST_TIMEOUT_ABORT)

    thread_name = threading.current_thread().name
    print(f"\n({thread_name}) Stress Test with [{n_runs}] calls \n to : [{url}]")
    print(results)

    if results.status != 0:
        failed_count += 1
        stress_test_progression.failed_threads_count += 1
        stress_test_progression.failed_stress_test_results.append(results)
        failed_results = f"{failed_results}\n{results}"

    assert failed_count == 0, f"Failed {failed_count} tests.  Failed results: {failed_results}"
    print(f"\n{thread_name} : All tests passed!")

# %% [markdown]
# ## Tests

# %%
# NBVAL_IGNORE_OUTPUT

# Executing WPS test on multiple threads
wps_urls = [
    f"{TWITCHER_URL}/{bird}/wps?service=wps&request=getcapabilities"
    for bird in TEST_WPS_BIRDS
]

for execution, wps_url in enumerate(wps_urls):
    run_threads(target_test = stress_test,
                url = wps_url,
                execution_id = execution,
                n_threads = TEST_N_THREADS_WPS,
                runs_per_threads = TEST_RUNS_WPS)

# %%
# NBVAL_IGNORE_OUTPUT

# Executing THREDDS test on multiple threads
thredds_url = f"{TWITCHER_URL}/thredds/catalog/birdhouse/testdata/catalog.html?dataset=birdhouse/testdata/ta_Amon_MRI-CGCM3_decadal1980_r1i1p1_199101-200012.nc"

run_threads(target_test = stress_test,
            url = thredds_url,
            n_threads = TEST_N_THREADS_THREDDS,
            runs_per_threads = TEST_RUNS_THREDDS)
# Out:
# --------------------------------------------------------------------------------------------------------
# URL Execution-1
# - Starting 5 threads with 500 runs per threads targeting "stress_test" function.
# - URL : https://pavics.ouranos.ca/twitcher/ows/proxy/thredds/catalog/birdhouse/testdata/catalog.html?dataset=birdhouse/testdata/ta_Amon_MRI-CGCM3_decadal1980_r1i1p1_199101-200012.nc
# - Initial progression values : {'count': 0, 'n_threads': 5, 'runs_per_threads': 500, 'total_runs': 2500, 'failed_threads_count': 0, 'failed_requests_count': 0, 'failed_stress_test_results': []}
# --------------------------------------------------------------------------------------------------------
#     Thread-1 --> Progress : 50/2500
#     Thread-5 --> Progress : 100/2500
#     Thread-3 --> Progress : 150/2500
#     Thread-4 --> Progress : 200/2500
#     Thread-2 --> Progress : 250/2500
#     Thread-5 --> Progress : 300/2500
#     Thread-4 --> Progress : 350/2500
#     Thread-3 --> Progress : 400/2500
#     Thread-1 --> Progress : 450/2500
#     Thread-2 --> Progress : 500/2500
#     Thread-5 --> Progress : 550/2500
#     Thread-4 --> Progress : 600/2500
#     Thread-1 --> Progress : 650/2500
#     Thread-2 --> Progress : 700/2500
#     Thread-3 --> Progress : 750/2500
#     Thread-5 --> Progress : 800/2500
#     Thread-4 --> Progress : 850/2500
#     Thread-1 --> Progress : 900/2500
#     Thread-2 --> Progress : 950/2500
#     Thread-3 --> Progress : 1000/2500
#     Thread-5 --> Progress : 1050/2500
#     Thread-4 --> Progress : 1100/2500
#     Thread-1 --> Progress : 1150/2500
#     Thread-2 --> Progress : 1200/2500
#     Thread-3 --> Progress : 1250/2500
#     Thread-5 --> Progress : 1300/2500
#     Thread-4 --> Progress : 1350/2500
#     Thread-1 --> Progress : 1400/2500
#     Thread-3 --> Progress : 1450/2500
#     Thread-2 --> Progress : 1500/2500
#     Thread-5 --> Progress : 1550/2500
#     Thread-1 --> Progress : 1600/2500
#     Thread-4 --> Progress : 1650/2500
#     Thread-3 --> Progress : 1700/2500
#     Thread-2 --> Progress : 1750/2500
#     Thread-5 --> Progress : 1800/2500
#     Thread-1 --> Progress : 1850/2500
#     Thread-4 --> Progress : 1900/2500
#     Thread-3 --> Progress : 1950/2500
#     Thread-2 --> Progress : 2000/2500
#     Thread-5 --> Progress : 2050/2500
#     Thread-1 --> Progress : 2100/2500
#     Thread-4 --> Progress : 2150/2500
#     Thread-3 --> Progress : 2200/2500
#     Thread-2 --> Progress : 2250/2500
#     Thread-5 --> Progress : 2300/2500
#     Thread-1 --> Progress : 2350/2500
#     Thread-4 --> Progress : 2400/2500
#     Thread-3 --> Progress : 2450/2500
#     Thread-2 --> Progress : 2500/2500
#
# (Thread-5) Stress Test with [500] calls
#  to : [https://pavics.ouranos.ca/twitcher/ows/proxy/thredds/catalog/birdhouse/testdata/catalog.html?dataset=birdhouse/testdata/ta_Amon_MRI-CGCM3_decadal1980_r1i1p1_199101-200012.nc]
# Stress Test:
#     Test:
#         code: 200
#         runs: 500
#         max-avg-time:  1s
#         max-err-code:  0
#         sum-err-code:  0
#         timeout-abort: 0s
#         timeout-retry: 0
#         timeout-count: 0
#     Request:
#         method: GET
#         url:    https://pavics.ouranos.ca/twitcher/ows/proxy/thredds/catalog/birdhouse/testdata/catalog.html?dataset=birdhouse/testdata/ta_Amon_MRI-CGCM3_decadal1980_r1i1p1_199101-200012.nc
#         args:   {}
#     Times:
#         min: 0.091s
#         avg: 0.140s
#         max: 0.351s
#     Results:
#         Run                 Codes                 Delta                 Times            Timestamps
#           1                   200                0.000s                0.214s   2023-09-13 12:45:01
#           2                   200                0.056s                0.151s   2023-09-13 12:45:02
#           3                   200                0.022s                0.115s   2023-09-13 12:45:02
#           4                   200                0.064s                0.191s   2023-09-13 12:45:02
#           5                   200                0.068s                0.217s   2023-09-13 12:45:02
#           6                   200                0.033s                0.176s   2023-09-13 12:45:03
#           7                   200                0.042s                0.134s   2023-09-13 12:45:03
#           8                   200                0.061s                0.191s   2023-09-13 12:45:03
#           9                   200                0.097s                0.134s   2023-09-13 12:45:03
#          10                   200                0.018s                0.130s   2023-09-13 12:45:03
#          11                   200                0.061s                0.129s   2023-09-13 12:45:03
#          12                   200                0.010s                0.124s   2023-09-13 12:45:04
#          13                   200                0.005s                0.109s   2023-09-13 12:45:04
#          14                   200                0.042s                0.111s   2023-09-13 12:45:04
#          15                   200                0.020s                0.124s   2023-09-13 12:45:04
#          16                   200                0.060s                0.107s   2023-09-13 12:45:04
#          17                   200                0.094s                0.119s   2023-09-13 12:45:04
#          18                   200                0.007s                0.128s   2023-09-13 12:45:05
#          19                   200                0.087s                0.144s   2023-09-13 12:45:05
#          20                   200                0.088s                0.141s   2023-09-13 12:45:05
#          21                   200                0.007s                0.116s   2023-09-13 12:45:05
#          22                   200                0.014s                0.107s   2023-09-13 12:45:05
#          23                   200                0.032s                0.114s   2023-09-13 12:45:05
#          24                   200                0.064s                0.111s   2023-09-13 12:45:06
#          25                   200                0.036s                0.106s   2023-09-13 12:45:06
#          26                   200                0.092s                0.130s   2023-09-13 12:45:06
#          27                   200                0.032s                0.091s   2023-09-13 12:45:06
#          28                   200                0.027s                0.098s   2023-09-13 12:45:06
#          29                   200                0.093s                0.132s   2023-09-13 12:45:06
#          30                   200                0.064s                0.147s   2023-09-13 12:45:07
#          31                   200                0.046s                0.109s   2023-09-13 12:45:07
#          32                   200                0.010s                0.119s   2023-09-13 12:45:07
#          33                   200                0.042s                0.126s   2023-09-13 12:45:07
#          34                   200                0.005s                0.132s   2023-09-13 12:45:07
#          35                   200                0.033s                0.129s   2023-09-13 12:45:07
#          36                   200                0.004s                0.104s   2023-09-13 12:45:08
#          37                   200                0.001s                0.119s   2023-09-13 12:45:08
#          38                   200                0.079s                0.120s   2023-09-13 12:45:08
#          39                   200                0.006s                0.125s   2023-09-13 12:45:08
#          40                   200                0.006s                0.146s   2023-09-13 12:45:08
#          41                   200                0.039s                0.147s   2023-09-13 12:45:08
#          42                   200                0.024s                0.147s   2023-09-13 12:45:09
#          43                   200                0.003s                0.122s   2023-09-13 12:45:09
#          44                   200                0.005s                0.138s   2023-09-13 12:45:09
#          45                   200                0.087s                0.132s   2023-09-13 12:45:09
#          46                   200                0.026s                0.129s   2023-09-13 12:45:09
#          47                   200                0.093s                0.133s   2023-09-13 12:45:09
#          48                   200                0.046s                0.179s   2023-09-13 12:45:10
#          49                   200                0.081s                0.125s   2023-09-13 12:45:10
#          50                   200                0.049s                0.160s   2023-09-13 12:45:10
#          51                   200                0.027s                0.128s   2023-09-13 12:45:10
#          52                   200                0.075s                0.135s   2023-09-13 12:45:10
#          53                   200                0.040s                0.135s   2023-09-13 12:45:11
#          54                   200                0.088s                0.128s   2023-09-13 12:45:11
#          55                   200                0.004s                0.122s   2023-09-13 12:45:11
#          56                   200                0.023s                0.130s   2023-09-13 12:45:11
#          57                   200                0.007s                0.126s   2023-09-13 12:45:11
#          58                   200                0.088s                0.150s   2023-09-13 12:45:11
#          59                   200                0.047s                0.102s   2023-09-13 12:45:12
#          60                   200                0.058s                0.122s   2023-09-13 12:45:12
#          61                   200                0.065s                0.131s   2023-09-13 12:45:12
#          62                   200                0.032s                0.116s   2023-09-13 12:45:12
#          63                   200                0.023s                0.124s   2023-09-13 12:45:12
#          64                   200                0.084s                0.143s   2023-09-13 12:45:12
#          65                   200                0.044s                0.132s   2023-09-13 12:45:13
#          66                   200                0.024s                0.131s   2023-09-13 12:45:13
#          67                   200                0.041s                0.125s   2023-09-13 12:45:13
#          68                   200                0.007s                0.128s   2023-09-13 12:45:13
#          69                   200                0.084s                0.144s   2023-09-13 12:45:13
#          70                   200                0.078s                0.134s   2023-09-13 12:45:14
#          71                   200                0.100s                0.134s   2023-09-13 12:45:14
#          72                   200                0.011s                0.119s   2023-09-13 12:45:14
#          73                   200                0.030s                0.120s   2023-09-13 12:45:14
#          74                   200                0.045s                0.116s   2023-09-13 12:45:14
#          75                   200                0.033s                0.144s   2023-09-13 12:45:14
#          76                   200                0.044s                0.130s   2023-09-13 12:45:15
#          77                   200                0.047s                0.141s   2023-09-13 12:45:15
#          78                   200                0.016s                0.140s   2023-09-13 12:45:15
#          79                   200                0.051s                0.120s   2023-09-13 12:45:15
#          80                   200                0.015s                0.125s   2023-09-13 12:45:15
#          81                   200                0.068s                0.134s   2023-09-13 12:45:15
#          82                   200                0.029s                0.170s   2023-09-13 12:45:16
#          83                   200                0.074s                0.113s   2023-09-13 12:45:16
#          84                   200                0.051s                0.122s   2023-09-13 12:45:16
#          85                   200                0.052s                0.103s   2023-09-13 12:45:16
#          86                   200                0.094s                0.117s   2023-09-13 12:45:16
#          87                   200                0.025s                0.115s   2023-09-13 12:45:17
#          88                   200                0.012s                0.116s   2023-09-13 12:45:17
#          89                   200                0.091s                0.112s   2023-09-13 12:45:17
#          90                   200                0.095s                0.110s   2023-09-13 12:45:17
#          91                   200                0.047s                0.100s   2023-09-13 12:45:17
#          92                   200                0.006s                0.106s   2023-09-13 12:45:17
#          93                   200                0.090s                0.102s   2023-09-13 12:45:17
#          94                   200                0.037s                0.111s   2023-09-13 12:45:18
#          95                   200                0.045s                0.116s   2023-09-13 12:45:18
#          96                   200                0.032s                0.106s   2023-09-13 12:45:18
#          97                   200                0.053s                0.164s   2023-09-13 12:45:18
#          98                   200                0.063s                0.127s   2023-09-13 12:45:18
#          99                   200                0.086s                0.132s   2023-09-13 12:45:19
#         100                   200                0.058s                0.148s   2023-09-13 12:45:19
#         101                   200                0.034s                0.104s   2023-09-13 12:45:19
#         102                   200                0.087s                0.110s   2023-09-13 12:45:19
#         103                   200                0.033s                0.137s   2023-09-13 12:45:19
#         104                   200                0.088s                0.142s   2023-09-13 12:45:20
#         105                   200                0.035s                0.102s   2023-09-13 12:45:20
#         106                   200                0.057s                0.351s   2023-09-13 12:45:20
#         107                   200                0.046s                0.108s   2023-09-13 12:45:20
#         108                   200                0.024s                0.161s   2023-09-13 12:45:20
#         109                   200                0.076s                0.133s   2023-09-13 12:45:21
#         110                   200                0.013s                0.113s   2023-09-13 12:45:21
#         111                   200                0.088s                0.123s   2023-09-13 12:45:21
#         112                   200                0.044s                0.106s   2023-09-13 12:45:21
#         113                   200                0.084s                0.116s   2023-09-13 12:45:21
#         114                   200                0.057s                0.143s   2023-09-13 12:45:22
#         115                   200                0.002s                0.106s   2023-09-13 12:45:22
#         116                   200                0.014s                0.108s   2023-09-13 12:45:22
#         117                   200                0.018s                0.096s   2023-09-13 12:45:22
#         118                   200                0.099s                0.120s   2023-09-13 12:45:22
#         119                   200                0.066s                0.128s   2023-09-13 12:45:22
#         120                   200                0.056s                0.131s   2023-09-13 12:45:23
#         121                   200                0.026s                0.134s   2023-09-13 12:45:23
#         122                   200                0.063s                0.130s   2023-09-13 12:45:23
#         123                   200                0.007s                0.113s   2023-09-13 12:45:23
#         124                   200                0.018s                0.106s   2023-09-13 12:45:23
#         125                   200                0.057s                0.110s   2023-09-13 12:45:23
#         126                   200                0.019s                0.091s   2023-09-13 12:45:23
#         127                   200                0.095s                0.136s   2023-09-13 12:45:24
#         128                   200                0.053s                0.125s   2023-09-13 12:45:24
#         129                   200                0.083s                0.119s   2023-09-13 12:45:24
#         130                   200                0.038s                0.105s   2023-09-13 12:45:24
#         131                   200                0.022s                0.099s   2023-09-13 12:45:24
#         132                   200                0.035s                0.135s   2023-09-13 12:45:24
#         133                   200                0.074s                0.138s   2023-09-13 12:45:25
#         134                   200                0.008s                0.118s   2023-09-13 12:45:25
#         135                   200                0.038s                0.145s   2023-09-13 12:45:25
#         136                   200                0.080s                0.133s   2023-09-13 12:45:25
#         137                   200                0.098s                0.120s   2023-09-13 12:45:25
#         138                   200                0.020s                0.176s   2023-09-13 12:45:26
#         139                   200                0.079s                0.105s   2023-09-13 12:45:26
#         140                   200                0.029s                0.121s   2023-09-13 12:45:26
#         141                   200                0.073s                0.110s   2023-09-13 12:45:26
#         142                   200                0.037s                0.136s   2023-09-13 12:45:26
#         143                   200                0.009s                0.127s   2023-09-13 12:45:26
#         144                   200                0.087s                0.168s   2023-09-13 12:45:27
#         145                   200                0.050s                0.122s   2023-09-13 12:45:27
#         146                   200                0.025s                0.124s   2023-09-13 12:45:27
#         147                   200                0.068s                0.115s   2023-09-13 12:45:27
#         148                   200                0.040s                0.144s   2023-09-13 12:45:27
#         149                   200                0.025s                0.131s   2023-09-13 12:45:28
#         150                   200                0.097s                0.127s   2023-09-13 12:45:28
#         151                   200                0.091s                0.137s   2023-09-13 12:45:28
#         152                   200                0.085s                0.125s   2023-09-13 12:45:28
#         153                   200                0.083s                0.122s   2023-09-13 12:45:28
#         154                   200                0.079s                0.131s   2023-09-13 12:45:29
#         155                   200                0.038s                0.154s   2023-09-13 12:45:29
#         156                   200                0.022s                0.171s   2023-09-13 12:45:29
#         157                   200                0.011s                0.155s   2023-09-13 12:45:29
#         158                   200                0.009s                0.113s   2023-09-13 12:45:29
#         159                   200                0.002s                0.155s   2023-09-13 12:45:30
#         160                   200                0.038s                0.141s   2023-09-13 12:45:30
#         161                   200                0.010s                0.122s   2023-09-13 12:45:30
#         162                   200                0.081s                0.121s   2023-09-13 12:45:30
#         163                   200                0.025s                0.138s   2023-09-13 12:45:30
#         164                   200                0.044s                0.126s   2023-09-13 12:45:30
#         165                   200                0.055s                0.126s   2023-09-13 12:45:30
#         166                   200                0.011s                0.095s   2023-09-13 12:45:31
#         167                   200                0.070s                0.137s   2023-09-13 12:45:31
#         168                   200                0.031s                0.111s   2023-09-13 12:45:31
#         169                   200                0.023s                0.117s   2023-09-13 12:45:31
#         170                   200                0.027s                0.109s   2023-09-13 12:45:31
#         171                   200                0.039s                0.118s   2023-09-13 12:45:31
#         172                   200                0.072s                0.139s   2023-09-13 12:45:32
#         173                   200                0.017s                0.140s   2023-09-13 12:45:32
#         174                   200                0.088s                0.137s   2023-09-13 12:45:32
#         175                   200                0.055s                0.125s   2023-09-13 12:45:32
#         176                   200                0.048s                0.112s   2023-09-13 12:45:32
#         177                   200                0.071s                0.133s   2023-09-13 12:45:33
#         178                   200                0.037s                0.139s   2023-09-13 12:45:33
#         179                   200                0.087s                0.123s   2023-09-13 12:45:33
#         180                   200                0.077s                0.126s   2023-09-13 12:45:33
#         181                   200                0.073s                0.149s   2023-09-13 12:45:33
#         182                   200                0.098s                0.153s   2023-09-13 12:45:34
#         183                   200                0.090s                0.114s   2023-09-13 12:45:34
#         184                   200                0.034s                0.125s   2023-09-13 12:45:34
#         185                   200                0.066s                0.115s   2023-09-13 12:45:34
#         186                   200                0.068s                0.122s   2023-09-13 12:45:34
#         187                   200                0.050s                0.112s   2023-09-13 12:45:35
#         188                   200                0.015s                0.133s   2023-09-13 12:45:35
#         189                   200                0.002s                0.106s   2023-09-13 12:45:35
#         190                   200                0.068s                0.151s   2023-09-13 12:45:35
#         191                   200                0.037s                0.118s   2023-09-13 12:45:35
#         192                   200                0.002s                0.109s   2023-09-13 12:45:35
#         193                   200                0.067s                0.129s   2023-09-13 12:45:35
#         194                   200                0.033s                0.107s   2023-09-13 12:45:36
#         195                   200                0.087s                0.144s   2023-09-13 12:45:36
#         196                   200                0.088s                0.129s   2023-09-13 12:45:36
#         197                   200                0.061s                0.110s   2023-09-13 12:45:36
#         198                   200                0.056s                0.112s   2023-09-13 12:45:36
#         199                   200                0.006s                0.136s   2023-09-13 12:45:37
#         200                   200                0.014s                0.117s   2023-09-13 12:45:37
#         201                   200                0.073s                0.147s   2023-09-13 12:45:37
#         202                   200                0.017s                0.145s   2023-09-13 12:45:37
#         203                   200                0.045s                0.135s   2023-09-13 12:45:37
#         204                   200                0.018s                0.121s   2023-09-13 12:45:37
#         205                   200                0.040s                0.139s   2023-09-13 12:45:38
#         206                   200                0.027s                0.124s   2023-09-13 12:45:38
#         207                   200                0.092s                0.131s   2023-09-13 12:45:38
#         208                   200                0.048s                0.126s   2023-09-13 12:45:38
#         209                   200                0.040s                0.120s   2023-09-13 12:45:38
#         210                   200                0.058s                0.115s   2023-09-13 12:45:38
#         211                   200                0.035s                0.113s   2023-09-13 12:45:39
#         212                   200                0.079s                0.143s   2023-09-13 12:45:39
#         213                   200                0.050s                0.136s   2023-09-13 12:45:39
#         214                   200                0.013s                0.133s   2023-09-13 12:45:39
#         215                   200                0.026s                0.128s   2023-09-13 12:45:39
#         216                   200                0.048s                0.127s   2023-09-13 12:45:39
#         217                   200                0.100s                0.107s   2023-09-13 12:45:40
#         218                   200                0.051s                0.125s   2023-09-13 12:45:40
#         219                   200                0.065s                0.129s   2023-09-13 12:45:40
#         220                   200                0.005s                0.128s   2023-09-13 12:45:40
#         221                   200                0.064s                0.131s   2023-09-13 12:45:40
#         222                   200                0.066s                0.145s   2023-09-13 12:45:41
#         223                   200                0.047s                0.150s   2023-09-13 12:45:41
#         224                   200                0.039s                0.139s   2023-09-13 12:45:41
#         225                   200                0.034s                0.134s   2023-09-13 12:45:41
#         226                   200                0.066s                0.199s   2023-09-13 12:45:41
#         227                   200                0.022s                0.121s   2023-09-13 12:45:42
#         228                   200                0.049s                0.129s   2023-09-13 12:45:42
#         229                   200                0.038s                0.114s   2023-09-13 12:45:42
#         230                   200                0.045s                0.120s   2023-09-13 12:45:42
#         231                   200                0.081s                0.134s   2023-09-13 12:45:42
#         232                   200                0.023s                0.197s   2023-09-13 12:45:43
#         233                   200                0.094s                0.141s   2023-09-13 12:45:43
#         234                   200                0.053s                0.159s   2023-09-13 12:45:43
#         235                   200                0.055s                0.165s   2023-09-13 12:45:43
#         236                   200                0.040s                0.127s   2023-09-13 12:45:43
#         237                   200                0.017s                0.116s   2023-09-13 12:45:44
#         238                   200                0.004s                0.140s   2023-09-13 12:45:44
#         239                   200                0.019s                0.114s   2023-09-13 12:45:44
#         240                   200                0.014s                0.118s   2023-09-13 12:45:44
#         241                   200                0.043s                0.118s   2023-09-13 12:45:44
#         242                   200                0.021s                0.112s   2023-09-13 12:45:44
#         243                   200                0.032s                0.116s   2023-09-13 12:45:44
#         244                   200                0.044s                0.119s   2023-09-13 12:45:45
#         245                   200                0.100s                0.131s   2023-09-13 12:45:45
#         246                   200                0.076s                0.117s   2023-09-13 12:45:45
#         247                   200                0.097s                0.120s   2023-09-13 12:45:45
#         248                   200                0.064s                0.130s   2023-09-13 12:45:45
#         249                   200                0.083s                0.138s   2023-09-13 12:45:46
#         250                   200                0.070s                0.134s   2023-09-13 12:45:46
#         251                   200                0.008s                0.124s   2023-09-13 12:45:46
#         252                   200                0.063s                0.156s   2023-09-13 12:45:46
#         253                   200                0.063s                0.186s   2023-09-13 12:45:46
#         254                   200                0.098s                0.193s   2023-09-13 12:45:47
#         255                   200                0.075s                0.142s   2023-09-13 12:45:47
#         256                   200                0.060s                0.133s   2023-09-13 12:45:47
#         257                   200                0.012s                0.130s   2023-09-13 12:45:47
#         258                   200                0.076s                0.111s   2023-09-13 12:45:47
#         259                   200                0.050s                0.149s   2023-09-13 12:45:48
#         260                   200                0.034s                0.129s   2023-09-13 12:45:48
#         261                   200                0.014s                0.130s   2023-09-13 12:45:48
#         262                   200                0.015s                0.133s   2023-09-13 12:45:48
#         263                   200                0.056s                0.152s   2023-09-13 12:45:48
#         264                   200                0.082s                0.143s   2023-09-13 12:45:48
#         265                   200                0.069s                0.129s   2023-09-13 12:45:49
#         266                   200                0.032s                0.149s   2023-09-13 12:45:49
#         267                   200                0.054s                0.142s   2023-09-13 12:45:49
#         268                   200                0.042s                0.141s   2023-09-13 12:45:49
#         269                   200                0.085s                0.189s   2023-09-13 12:45:50
#         270                   200                0.022s                0.148s   2023-09-13 12:45:50
#         271                   200                0.060s                0.136s   2023-09-13 12:45:50
#         272                   200                0.059s                0.122s   2023-09-13 12:45:50
#         273                   200                0.014s                0.124s   2023-09-13 12:45:50
#         274                   200                0.023s                0.136s   2023-09-13 12:45:50
#         275                   200                0.098s                0.122s   2023-09-13 12:45:51
#         276                   200                0.026s                0.148s   2023-09-13 12:45:51
#         277                   200                0.092s                0.105s   2023-09-13 12:45:51
#         278                   200                0.093s                0.121s   2023-09-13 12:45:51
#         279                   200                0.003s                0.129s   2023-09-13 12:45:51
#         280                   200                0.072s                0.126s   2023-09-13 12:45:52
#         281                   200                0.075s                0.136s   2023-09-13 12:45:52
#         282                   200                0.011s                0.131s   2023-09-13 12:45:52
#         283                   200                0.005s                0.114s   2023-09-13 12:45:52
#         284                   200                0.032s                0.101s   2023-09-13 12:45:52
#         285                   200                0.023s                0.115s   2023-09-13 12:45:52
#         286                   200                0.012s                0.127s   2023-09-13 12:45:52
#         287                   200                0.048s                0.134s   2023-09-13 12:45:53
#         288                   200                0.061s                0.150s   2023-09-13 12:45:53
#         289                   200                0.021s                0.149s   2023-09-13 12:45:53
#         290                   200                0.004s                0.147s   2023-09-13 12:45:53
#         291                   200                0.092s                0.132s   2023-09-13 12:45:53
#         292                   200                0.079s                0.129s   2023-09-13 12:45:54
#         293                   200                0.052s                0.118s   2023-09-13 12:45:54
#         294                   200                0.049s                0.112s   2023-09-13 12:45:54
#         295                   200                0.092s                0.129s   2023-09-13 12:45:54
#         296                   200                0.013s                0.125s   2023-09-13 12:45:54
#         297                   200                0.094s                0.119s   2023-09-13 12:45:54
#         298                   200                0.035s                0.127s   2023-09-13 12:45:55
#         299                   200                0.079s                0.120s   2023-09-13 12:45:55
#         300                   200                0.086s                0.116s   2023-09-13 12:45:55
#         301                   200                0.065s                0.118s   2023-09-13 12:45:55
#         302                   200                0.087s                0.144s   2023-09-13 12:45:55
#         303                   200                0.022s                0.171s   2023-09-13 12:45:56
#         304                   200                0.040s                0.238s   2023-09-13 12:45:56
#         305                   200                0.077s                0.212s   2023-09-13 12:45:56
#         306                   200                0.007s                0.223s   2023-09-13 12:45:57
#         307                   200                0.068s                0.185s   2023-09-13 12:45:57
#         308                   200                0.055s                0.199s   2023-09-13 12:45:57
#         309                   200                0.049s                0.134s   2023-09-13 12:45:57
#         310                   200                0.046s                0.122s   2023-09-13 12:45:57
#         311                   200                0.004s                0.135s   2023-09-13 12:45:58
#         312                   200                0.054s                0.137s   2023-09-13 12:45:58
#         313                   200                0.075s                0.114s   2023-09-13 12:45:58
#         314                   200                0.013s                0.143s   2023-09-13 12:45:58
#         315                   200                0.063s                0.167s   2023-09-13 12:45:58
#         316                   200                0.046s                0.189s   2023-09-13 12:45:59
#         317                   200                0.022s                0.146s   2023-09-13 12:45:59
#         318                   200                0.053s                0.141s   2023-09-13 12:45:59
#         319                   200                0.019s                0.144s   2023-09-13 12:45:59
#         320                   200                0.049s                0.126s   2023-09-13 12:45:59
#         321                   200                0.046s                0.171s   2023-09-13 12:45:59
#         322                   200                0.042s                0.250s   2023-09-13 12:46:00
#         323                   200                0.078s                0.147s   2023-09-13 12:46:00
#         324                   200                0.079s                0.135s   2023-09-13 12:46:00
#         325                   200                0.043s                0.144s   2023-09-13 12:46:00
#         326                   200                0.008s                0.106s   2023-09-13 12:46:01
#         327                   200                0.086s                0.116s   2023-09-13 12:46:01
#         328                   200                0.033s                0.300s   2023-09-13 12:46:01
#         329                   200                0.055s                0.325s   2023-09-13 12:46:01
#         330                   200                0.055s                0.161s   2023-09-13 12:46:02
#         331                   200                0.033s                0.126s   2023-09-13 12:46:02
#         332                   200                0.010s                0.150s   2023-09-13 12:46:02
#         333                   200                0.027s                0.213s   2023-09-13 12:46:02
#         334                   200                0.044s                0.279s   2023-09-13 12:46:03
#         335                   200                0.055s                0.199s   2023-09-13 12:46:03
#         336                   200                0.086s                0.173s   2023-09-13 12:46:03
#         337                   200                0.006s                0.138s   2023-09-13 12:46:03
#         338                   200                0.016s                0.137s   2023-09-13 12:46:03
#         339                   200                0.085s                0.212s   2023-09-13 12:46:04
#         340                   200                0.082s                0.202s   2023-09-13 12:46:04
#         341                   200                0.071s                0.280s   2023-09-13 12:46:04
#         342                   200                0.053s                0.213s   2023-09-13 12:46:05
#         343                   200                0.098s                0.299s   2023-09-13 12:46:05
#         344                   200                0.082s                0.198s   2023-09-13 12:46:05
#         345                   200                0.041s                0.160s   2023-09-13 12:46:05
#         346                   200                0.099s                0.152s   2023-09-13 12:46:06
#         347                   200                0.010s                0.111s   2023-09-13 12:46:06
#         348                   200                0.098s                0.127s   2023-09-13 12:46:06
#         349                   200                0.011s                0.159s   2023-09-13 12:46:06
#         350                   200                0.096s                0.100s   2023-09-13 12:46:06
#         351                   200                0.078s                0.126s   2023-09-13 12:46:07
#         352                   200                0.078s                0.120s   2023-09-13 12:46:07
#         353                   200                0.097s                0.107s   2023-09-13 12:46:07
#         354                   200                0.012s                0.185s   2023-09-13 12:46:07
#         355                   200                0.053s                0.158s   2023-09-13 12:46:07
#         356                   200                0.020s                0.138s   2023-09-13 12:46:08
#         357                   200                0.019s                0.125s   2023-09-13 12:46:08
#         358                   200                0.042s                0.119s   2023-09-13 12:46:08
#         359                   200                0.031s                0.156s   2023-09-13 12:46:08
#         360                   200                0.090s                0.146s   2023-09-13 12:46:08
#         361                   200                0.058s                0.183s   2023-09-13 12:46:09
#         362                   200                0.052s                0.155s   2023-09-13 12:46:09
#         363                   200                0.002s                0.134s   2023-09-13 12:46:09
#         364                   200                0.029s                0.168s   2023-09-13 12:46:09
#         365                   200                0.041s                0.148s   2023-09-13 12:46:09
#         366                   200                0.100s                0.159s   2023-09-13 12:46:10
#         367                   200                0.097s                0.143s   2023-09-13 12:46:10
#         368                   200                0.016s                0.131s   2023-09-13 12:46:10
#         369                   200                0.003s                0.178s   2023-09-13 12:46:10
#         370                   200                0.098s                0.128s   2023-09-13 12:46:10
#         371                   200                0.093s                0.154s   2023-09-13 12:46:11
#         372                   200                0.047s                0.144s   2023-09-13 12:46:11
#         373                   200                0.076s                0.168s   2023-09-13 12:46:11
#         374                   200                0.076s                0.170s   2023-09-13 12:46:11
#         375                   200                0.015s                0.182s   2023-09-13 12:46:12
#         376                   200                0.040s                0.187s   2023-09-13 12:46:12
#         377                   200                0.031s                0.154s   2023-09-13 12:46:12
#         378                   200                0.055s                0.150s   2023-09-13 12:46:12
#         379                   200                0.067s                0.139s   2023-09-13 12:46:12
#         380                   200                0.012s                0.218s   2023-09-13 12:46:13
#         381                   200                0.081s                0.166s   2023-09-13 12:46:13
#         382                   200                0.067s                0.135s   2023-09-13 12:46:13
#         383                   200                0.079s                0.152s   2023-09-13 12:46:13
#         384                   200                0.016s                0.145s   2023-09-13 12:46:13
#         385                   200                0.038s                0.160s   2023-09-13 12:46:14
#         386                   200                0.098s                0.133s   2023-09-13 12:46:14
#         387                   200                0.016s                0.161s   2023-09-13 12:46:14
#         388                   200                0.094s                0.159s   2023-09-13 12:46:14
#         389                   200                0.070s                0.124s   2023-09-13 12:46:14
#         390                   200                0.025s                0.150s   2023-09-13 12:46:15
#         391                   200                0.076s                0.156s   2023-09-13 12:46:15
#         392                   200                0.002s                0.149s   2023-09-13 12:46:15
#         393                   200                0.044s                0.164s   2023-09-13 12:46:15
#         394                   200                0.005s                0.122s   2023-09-13 12:46:15
#         395                   200                0.012s                0.128s   2023-09-13 12:46:16
#         396                   200                0.095s                0.145s   2023-09-13 12:46:16
#         397                   200                0.088s                0.130s   2023-09-13 12:46:16
#         398                   200                0.006s                0.144s   2023-09-13 12:46:16
#         399                   200                0.060s                0.117s   2023-09-13 12:46:16
#         400                   200                0.052s                0.153s   2023-09-13 12:46:17
#         401                   200                0.067s                0.131s   2023-09-13 12:46:17
#         402                   200                0.050s                0.226s   2023-09-13 12:46:17
#         403                   200                0.095s                0.173s   2023-09-13 12:46:17
#         404                   200                0.098s                0.144s   2023-09-13 12:46:17
#         405                   200                0.043s                0.146s   2023-09-13 12:46:18
#         406                   200                0.079s                0.147s   2023-09-13 12:46:18
#         407                   200                0.029s                0.127s   2023-09-13 12:46:18
#         408                   200                0.090s                0.151s   2023-09-13 12:46:18
#         409                   200                0.031s                0.144s   2023-09-13 12:46:19
#         410                   200                0.099s                0.160s   2023-09-13 12:46:19
#         411                   200                0.040s                0.119s   2023-09-13 12:46:19
#         412                   200                0.024s                0.138s   2023-09-13 12:46:19
#         413                   200                0.027s                0.154s   2023-09-13 12:46:19
#         414                   200                0.077s                0.122s   2023-09-13 12:46:19
#         415                   200                0.097s                0.116s   2023-09-13 12:46:20
#         416                   200                0.036s                0.122s   2023-09-13 12:46:20
#         417                   200                0.068s                0.119s   2023-09-13 12:46:20
#         418                   200                0.077s                0.176s   2023-09-13 12:46:20
#         419                   200                0.041s                0.135s   2023-09-13 12:46:20
#         420                   200                0.059s                0.147s   2023-09-13 12:46:21
#         421                   200                0.013s                0.130s   2023-09-13 12:46:21
#         422                   200                0.019s                0.183s   2023-09-13 12:46:21
#         423                   200                0.045s                0.130s   2023-09-13 12:46:21
#         424                   200                0.053s                0.120s   2023-09-13 12:46:21
#         425                   200                0.078s                0.130s   2023-09-13 12:46:22
#         426                   200                0.094s                0.135s   2023-09-13 12:46:22
#         427                   200                0.097s                0.142s   2023-09-13 12:46:22
#         428                   200                0.066s                0.140s   2023-09-13 12:46:22
#         429                   200                0.035s                0.106s   2023-09-13 12:46:22
#         430                   200                0.022s                0.143s   2023-09-13 12:46:23
#         431                   200                0.051s                0.163s   2023-09-13 12:46:23
#         432                   200                0.023s                0.124s   2023-09-13 12:46:23
#         433                   200                0.076s                0.150s   2023-09-13 12:46:23
#         434                   200                0.010s                0.123s   2023-09-13 12:46:23
#         435                   200                0.064s                0.146s   2023-09-13 12:46:23
#         436                   200                0.018s                0.153s   2023-09-13 12:46:24
#         437                   200                0.068s                0.133s   2023-09-13 12:46:24
#         438                   200                0.039s                0.123s   2023-09-13 12:46:24
#         439                   200                0.088s                0.149s   2023-09-13 12:46:24
#         440                   200                0.029s                0.141s   2023-09-13 12:46:24
#         441                   200                0.040s                0.174s   2023-09-13 12:46:25
#         442                   200                0.044s                0.140s   2023-09-13 12:46:25
#         443                   200                0.025s                0.169s   2023-09-13 12:46:25
#         444                   200                0.099s                0.142s   2023-09-13 12:46:25
# ...
#         343                   200                0.037s                0.163s   2023-09-13 12:46:07
#         344                   200                0.073s                0.152s   2023-09-13 12:46:08
#         345                   200                0.036s                0.138s   2023-09-13 12:46:08
#         346                   200                0.015s                0.138s   2023-09-13 12:46:08
#         347                   200                0.007s                0.148s   2023-09-13 12:46:08
#         348                   200                0.024s                0.166s   2023-09-13 12:46:08
#         349                   200                0.093s                0.168s   2023-09-13 12:46:08
#         350                   200                0.085s                0.148s   2023-09-13 12:46:09
#         351                   200                0.009s                0.160s   2023-09-13 12:46:09
#         352                   200                0.020s                0.178s   2023-09-13 12:46:09
#         353                   200                0.011s                0.149s   2023-09-13 12:46:09
#         354                   200                0.020s                0.167s   2023-09-13 12:46:09
#         355                   200                0.066s                0.126s   2023-09-13 12:46:10
#         356                   200                0.043s                0.131s   2023-09-13 12:46:10
#         357                   200                0.010s                0.145s   2023-09-13 12:46:10
#         358                   200                0.017s                0.133s   2023-09-13 12:46:10
#         359                   200                0.048s                0.122s   2023-09-13 12:46:10
#         360                   200                0.015s                0.137s   2023-09-13 12:46:10
#         361                   200                0.003s                0.149s   2023-09-13 12:46:11
#         362                   200                0.093s                0.184s   2023-09-13 12:46:11
#         363                   200                0.002s                0.154s   2023-09-13 12:46:11
#         364                   200                0.057s                0.147s   2023-09-13 12:46:11
#         365                   200                0.007s                0.202s   2023-09-13 12:46:11
#         366                   200                0.037s                0.154s   2023-09-13 12:46:12
#         367                   200                0.037s                0.158s   2023-09-13 12:46:12
#         368                   200                0.074s                0.178s   2023-09-13 12:46:12
#         369                   200                0.062s                0.141s   2023-09-13 12:46:12
#         370                   200                0.019s                0.151s   2023-09-13 12:46:12
#         371                   200                0.055s                0.214s   2023-09-13 12:46:13
#         372                   200                0.042s                0.133s   2023-09-13 12:46:13
#         373                   200                0.047s                0.154s   2023-09-13 12:46:13
#         374                   200                0.062s                0.126s   2023-09-13 12:46:13
#         375                   200                0.097s                0.152s   2023-09-13 12:46:14
#         376                   200                0.086s                0.136s   2023-09-13 12:46:14
#         377                   200                0.027s                0.144s   2023-09-13 12:46:14
#         378                   200                0.093s                0.142s   2023-09-13 12:46:14
#         379                   200                0.037s                0.127s   2023-09-13 12:46:14
#         380                   200                0.025s                0.169s   2023-09-13 12:46:15
#         381                   200                0.096s                0.137s   2023-09-13 12:46:15
#         382                   200                0.097s                0.129s   2023-09-13 12:46:15
#         383                   200                0.019s                0.143s   2023-09-13 12:46:15
#         384                   200                0.013s                0.149s   2023-09-13 12:46:15
#         385                   200                0.074s                0.136s   2023-09-13 12:46:16
#         386                   200                0.030s                0.106s   2023-09-13 12:46:16
#         387                   200                0.083s                0.140s   2023-09-13 12:46:16
#         388                   200                0.078s                0.155s   2023-09-13 12:46:16
#         389                   200                0.081s                0.121s   2023-09-13 12:46:16
#         390                   200                0.099s                0.173s   2023-09-13 12:46:17
#         391                   200                0.003s                0.154s   2023-09-13 12:46:17
#         392                   200                0.031s                0.212s   2023-09-13 12:46:17
#         393                   200                0.017s                0.131s   2023-09-13 12:46:17
#         394                   200                0.090s                0.167s   2023-09-13 12:46:17
#         395                   200                0.077s                0.121s   2023-09-13 12:46:18
#         396                   200                0.065s                0.134s   2023-09-13 12:46:18
#         397                   200                0.001s                0.151s   2023-09-13 12:46:18
#         398                   200                0.018s                0.130s   2023-09-13 12:46:18
#         399                   200                0.004s                0.149s   2023-09-13 12:46:18
#         400                   200                0.059s                0.133s   2023-09-13 12:46:18
#         401                   200                0.001s                0.137s   2023-09-13 12:46:19
#         402                   200                0.075s                0.147s   2023-09-13 12:46:19
#         403                   200                0.010s                0.126s   2023-09-13 12:46:19
#         404                   200                0.067s                0.154s   2023-09-13 12:46:19
#         405                   200                0.086s                0.142s   2023-09-13 12:46:19
#         406                   200                0.083s                0.119s   2023-09-13 12:46:20
#         407                   200                0.019s                0.163s   2023-09-13 12:46:20
#         408                   200                0.007s                0.141s   2023-09-13 12:46:20
#         409                   200                0.018s                0.158s   2023-09-13 12:46:20
#         410                   200                0.029s                0.152s   2023-09-13 12:46:20
#         411                   200                0.084s                0.132s   2023-09-13 12:46:21
#         412                   200                0.053s                0.165s   2023-09-13 12:46:21
#         413                   200                0.074s                0.136s   2023-09-13 12:46:21
#         414                   200                0.042s                0.119s   2023-09-13 12:46:21
#         415                   200                0.071s                0.142s   2023-09-13 12:46:21
#         416                   200                0.027s                0.157s   2023-09-13 12:46:22
#         417                   200                0.093s                0.159s   2023-09-13 12:46:22
#         418                   200                0.018s                0.176s   2023-09-13 12:46:22
#         419                   200                0.093s                0.148s   2023-09-13 12:46:22
#         420                   200                0.073s                0.125s   2023-09-13 12:46:22
#         421                   200                0.064s                0.117s   2023-09-13 12:46:23
#         422                   200                0.089s                0.159s   2023-09-13 12:46:23
#         423                   200                0.091s                0.138s   2023-09-13 12:46:23
#         424                   200                0.082s                0.122s   2023-09-13 12:46:23
#         425                   200                0.051s                0.150s   2023-09-13 12:46:23
#         426                   200                0.052s                0.145s   2023-09-13 12:46:24
#         427                   200                0.092s                0.145s   2023-09-13 12:46:24
#         428                   200                0.014s                0.136s   2023-09-13 12:46:24
#         429                   200                0.083s                0.139s   2023-09-13 12:46:24
#         430                   200                0.028s                0.121s   2023-09-13 12:46:24
#         431                   200                0.081s                0.181s   2023-09-13 12:46:25
#         432                   200                0.053s                0.155s   2023-09-13 12:46:25
#         433                   200                0.079s                0.157s   2023-09-13 12:46:25
#         434                   200                0.058s                0.141s   2023-09-13 12:46:25
#         435                   200                0.067s                0.196s   2023-09-13 12:46:26
#         436                   200                0.004s                0.161s   2023-09-13 12:46:26
#         437                   200                0.012s                0.187s   2023-09-13 12:46:26
#         438                   200                0.083s                0.147s   2023-09-13 12:46:26
#         439                   200                0.020s                0.132s   2023-09-13 12:46:26
#         440                   200                0.048s                0.144s   2023-09-13 12:46:27
#         441                   200                0.033s                0.131s   2023-09-13 12:46:27
#         442                   200                0.091s                0.120s   2023-09-13 12:46:27
#         443                   200                0.006s                0.187s   2023-09-13 12:46:27
#         444                   200                0.052s                0.156s   2023-09-13 12:46:27
#         445                   200                0.021s                0.155s   2023-09-13 12:46:28
#         446                   200                0.014s                0.168s   2023-09-13 12:46:28
#         447                   200                0.092s                0.150s   2023-09-13 12:46:28
#         448                   200                0.039s                0.145s   2023-09-13 12:46:28
#         449                   200                0.060s                0.195s   2023-09-13 12:46:28
#         450                   200                0.062s                0.170s   2023-09-13 12:46:29
#         451                   200                0.016s                0.121s   2023-09-13 12:46:29
#         452                   200                0.027s                0.121s   2023-09-13 12:46:29
#         453                   200                0.019s                0.192s   2023-09-13 12:46:29
#         454                   200                0.023s                0.146s   2023-09-13 12:46:29
#         455                   200                0.057s                0.137s   2023-09-13 12:46:30
#         456                   200                0.078s                0.131s   2023-09-13 12:46:30
#         457                   200                0.061s                0.149s   2023-09-13 12:46:30
#         458                   200                0.003s                0.162s   2023-09-13 12:46:30
#         459                   200                0.099s                0.151s   2023-09-13 12:46:30
#         460                   200                0.021s                0.146s   2023-09-13 12:46:31
#         461                   200                0.007s                0.188s   2023-09-13 12:46:31
#         462                   200                0.056s                0.135s   2023-09-13 12:46:31
#         463                   200                0.048s                0.154s   2023-09-13 12:46:31
#         464                   200                0.028s                0.155s   2023-09-13 12:46:31
#         465                   200                0.020s                0.156s   2023-09-13 12:46:32
#         466                   200                0.007s                0.133s   2023-09-13 12:46:32
#         467                   200                0.031s                0.139s   2023-09-13 12:46:32
#         468                   200                0.012s                0.150s   2023-09-13 12:46:32
#         469                   200                0.003s                0.154s   2023-09-13 12:46:32
#         470                   200                0.031s                0.137s   2023-09-13 12:46:32
#         471                   200                0.055s                0.155s   2023-09-13 12:46:32
#         472                   200                0.065s                0.167s   2023-09-13 12:46:33
#         473                   200                0.019s                0.140s   2023-09-13 12:46:33
#         474                   200                0.012s                0.155s   2023-09-13 12:46:33
#         475                   200                0.084s                0.262s   2023-09-13 12:46:33
#         476                   200                0.019s                0.122s   2023-09-13 12:46:34
#         477                   200                0.001s                0.155s   2023-09-13 12:46:34
#         478                   200                0.015s                0.153s   2023-09-13 12:46:34
#         479                   200                0.062s                0.141s   2023-09-13 12:46:34
#         480                   200                0.088s                0.165s   2023-09-13 12:46:34
#         481                   200                0.081s                0.125s   2023-09-13 12:46:35
#         482                   200                0.092s                0.130s   2023-09-13 12:46:35
#         483                   200                0.009s                0.195s   2023-09-13 12:46:35
#         484                   200                0.035s                0.132s   2023-09-13 12:46:35
#         485                   200                0.050s                0.157s   2023-09-13 12:46:35
#         486                   200                0.018s                0.150s   2023-09-13 12:46:36
#         487                   200                0.089s                0.137s   2023-09-13 12:46:36
#         488                   200                0.007s                0.158s   2023-09-13 12:46:36
#         489                   200                0.016s                0.118s   2023-09-13 12:46:36
#         490                   200                0.035s                0.143s   2023-09-13 12:46:36
#         491                   200                0.098s                0.142s   2023-09-13 12:46:36
#         492                   200                0.017s                0.138s   2023-09-13 12:46:37
#         493                   200                0.076s                0.137s   2023-09-13 12:46:37
#         494                   200                0.070s                0.178s   2023-09-13 12:46:37
#         495                   200                0.027s                0.139s   2023-09-13 12:46:37
#         496                   200                0.013s                0.119s   2023-09-13 12:46:37
#         497                   200                0.020s                0.175s   2023-09-13 12:46:38
#         498                   200                0.060s                0.140s   2023-09-13 12:46:38
#         499                   200                0.095s                0.156s   2023-09-13 12:46:38
#         500                   200                0.002s                0.126s   2023-09-13 12:46:38
#     Summary:
#         All passing conditions have been achieved.
#         Test succeeded (status=0).
#
# Thread-2 : All tests passed!
# All threads passed stress_test function.
